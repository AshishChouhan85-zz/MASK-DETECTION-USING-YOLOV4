# %%
# CONNECTING TO MY DRIVE
from google.colab import drive
drive.mount('/content/drive')

# %%
# CHECKING CONNECTION TO DRIVE AND GPU
# !ls '/content/drive/My Drive/YOLO'
# !nvidia-smi

# %%
# UNZIPPING THE FILES
# !unzip '/content/drive/My Drive/YOLO/DATA.zip' -d '/content/drive/My Drive/YOLO'

# %%
# CHANGING DIRECTORY
# %cd /content/drive/My Drive/YOLO

# %%
# CREATING LABELLED DATA FILE
# !python DATA/creating-files-data-and-name.py

# %%
# CREATING TRAIN AND TEST FILES
# !python DATA/creating-train-and-test-txt-files.py

# %%
# CHANGING DIRECTORY TO INSTALL WEIGHTS FOR YOLOV4
# %cd /content/drive/My Drive/YOLO/weights

# %%
# DOWNLOADING PRE TRAINED WEIGHTS FOR TRANSFER LEARNING
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# CHANGING DIRECTORY TO EDIT MAKEFILE
# %cd /content/drive/My Drive/YOLO/darknet

# %%
# EDITING MAKEFILE TO START TRAINING
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
# CHANGING DIRECTORY TO BEGIN TRAINING
# %cd /content/drive/My Drive/YOLO
# GIVING ACCESS
# !chmod +x ./darknet/darknet

# %%
# STARTING THE TRAINING
# !darknet/darknet detector train DATA/labelled_data.data darknet/cfg/yolov4-custom.cfg weights/yolov4.conv.137 -dont_show

# %%
# CONTINUING THE TRAINING FROM LAST WEIGHT
# !darknet/darknet detector train DATA/labelled_data.data darknet/cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -dont_show
